# %%
from datetime import datetime
import calendar

import numpy as np
import pandas as pd

from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf

from statsmodels.tsa.arima.model import ARIMA

# %matplotlib inline

# %% [markdown]
# # ARIMA

# %% [markdown]
# First we use classical statistics (ARIMA), with only house price data, to predict future house prices.

# %% [markdown]
# ## Data

# %% [markdown]
# Here we have data for "simple average house prices, by new/other dwellings, type of buyer and  region, United Kingdom, from 1992 (quarterly)".
#
# From this we want to extract prices for all dwellings. The easiest way to to this is in excel itself.

# %%
# Define date parser for reading CSV
def date_parser_func(x):
    quarter, year = x.split("-")
    month = int(quarter[1]) * 3
    return pd.Timestamp(int(year), month, calendar.monthrange(int(year), month)[1])

# %%
# Import clean CSV as DF
raw_house_price_df = pd.read_csv(
    'CleanData/quarterly_house_prices.csv',
    encoding='utf-8',
    header=0,
    index_col=False,
    parse_dates=[0],
    date_parser=date_parser_func
)
# Out:
# C:\Users\haydn\AppData\Local\Temp\ipykernel_13028\3462159518.py:2: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   raw_house_price_df = pd.read_csv(

# %%
raw_house_price_df.head(3)
# Out:
#      Quarter  Price
# 0 1992-06-30  62000
# 1 1992-09-30  64000
# 2 1992-12-31  59000

# %%
raw_house_price_df.dtypes
# Out:
# Quarter    datetime64[ns]
# Price               int64
# dtype: object

# %%
raw_house_price_df.plot(x='Quarter')
# Out:
# <Axes: xlabel='Quarter'>

# %% [markdown]
# ## Statistical Analysis

# %%
#Autocorrelation
autocorrelation_plot(raw_house_price_df['Price'])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
plot_acf(raw_house_price_df['Price'])

# %% [markdown]
# Significant autocorrelation but no real seasonality (amongst the quarters) it seems. What about when we look at returns?

# %%
raw_house_price_df.Price.pct_change()
# Out:
# 0           NaN
# 1      0.032258
# 2     -0.078125
# 3      0.016949
# 4      0.033333
#          ...
# 122   -0.031073
# 123   -0.043732
# 124   -0.003049
# 125    0.045872
# 126   -0.046784
# Name: Price, Length: 127, dtype: float64

# %%
raw_house_price_df['Return'] = raw_house_price_df['Price'].pct_change()

# %%
raw_house_price_df['Return'].plot()
# Out:
# <Axes: >

# %%
plot_acf(raw_house_price_df['Return'])

# %% [markdown]
# No autocorrelation here...

# %% [markdown]
# ## ARIMA Estimation

# %%
# Instantiate the model
arima_model = ARIMA(raw_house_price_df['Price'], order=(20, 1, 0))

# %%
# Fit model
arima_model_fit = arima_model.fit()
# Out:
# C:\Users\haydn\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'

# %%
print(arima_model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Price   No. Observations:                  127
# Model:                ARIMA(20, 1, 0)   Log Likelihood               -1317.397
# Date:                Sat, 16 Mar 2024   AIC                           2676.794
# Time:                        08:41:37   BIC                           2736.356
# Sample:                             0   HQIC                          2700.992
#                                 - 127
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0279      0.072     -0.388      0.698      -0.169       0.113
# ar.L2         -0.1390      0.097     -1.431      0.152      -0.329       0.051
# ar.L3         -0.0735      0.099     -0.742      0.458      -0.268       0.121
# ...

# %% [markdown]
# None of these lags are statistically signif. Try with 4-quarter lags:

# %%
# Fit less complex model
arima_model = ARIMA(raw_house_price_df['Price'], order=(4, 1, 0))
arima_model_fit = arima_model.fit()
print(arima_model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Price   No. Observations:                  127
# Model:                 ARIMA(4, 1, 0)   Log Likelihood               -1335.099
# Date:                Sat, 16 Mar 2024   AIC                           2680.199
# Time:                        08:48:08   BIC                           2694.380
# Sample:                             0   HQIC                          2685.960
#                                 - 127
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0920      0.079     -1.162      0.245      -0.247       0.063
# ar.L2         -0.0641      0.060     -1.076      0.282      -0.181       0.053
# ar.L3         -0.1347      0.075     -1.806      0.071      -0.281       0.011
# ...

# %%
# line plot of residuals
residuals = pd.DataFrame(arima_model_fit.resid)
residuals.plot()
pyplot.show()
# density plot of residuals
residuals.plot(kind='kde')
pyplot.show()
# summary stats of residuals
print(residuals.describe())
# Out:
#                   0
# count    127.000000
# mean    3002.594482
# std    10721.161431
# min   -49887.707770
# 25%    -1351.209756
# 50%     2348.409410
# 75%     6901.019758
# max    62000.000000

# %% [markdown]
# ## Rolling ARIMA Forecast
